# %%
import pandas as pd
data = pd.read_csv('data/Sichuan/all_feat_with_label.csv')

# %%
data.head()
# Out:
#                                           phone_no_m  opposite_count  \
# 0  672ddbf02a5544d32e4ecc9433b1981bffe23bf912273a...          1258.0
# 1  5e1272273e041e82cb275ae877710be98cdaf5b0a8f34d...           156.0
# 2  eaab3472ec87b076e69e6e8bb62b14341638fc63661a6c...          1152.0
# 3  0ce1bb415704178bf44e9c9b431a39b083a132c8e6d99f...          5083.0
# 4  28b87f35f63f65096a53e3a4c97eaffd4a6c43ffa7e92d...            61.0
#
#    opposite_unique  voccalltype1  imeis  voc_calltype1  city_name_call  \
# 0             95.0         649.0    2.0       0.515898             2.0
# 1             63.0          43.0    1.0       0.275641             1.0
# 2            124.0         779.0    4.0       0.676215             3.0
# 3           1229.0        1457.0    2.0       0.286642             3.0
# 4             47.0          19.0    1.0       0.311475             2.0
#
#    county_name_call  phone2opposite_mean  phone2opposite_median  ...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6106 entries, 0 to 6105
# Data columns (total 57 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   phone_no_m             6106 non-null   object
#  1   opposite_count         6025 non-null   float64
#  2   opposite_unique        6025 non-null   float64
#  3   voccalltype1           5989 non-null   float64
#  4   imeis                  5989 non-null   float64
#  5   voc_calltype1          5989 non-null   float64
#  6   city_name_call         5989 non-null   float64
#  7   county_name_call       5989 non-null   float64
#  8   phone2opposite_mean    6025 non-null   float64
#  9   phone2opposite_median  6025 non-null   float64
#  10  phone2opposite_max     6025 non-null   float64
#  11  phone2oppo_sum_mean    6025 non-null   float64
#  12  phone2oppo_sum_median  6025 non-null   float64
#  13  phone2oppo_sum_max     6025 non-null   float64
# ...
